# %% [markdown]
# ### **Load data**

# %%
import pandas as pd

def load_data(df):
    return pd.read_csv(file_path)

file_path = '../data/flight_df.csv' # period indicates getting out from directory to others

# Load dataset
df = load_data(file_path)
df.head()
# Out:
#    Age  Class  Flight Distance  Inflight wifi service  \
# 0   26      3             2062                      2
# 1   52      3              680                      5
# 2   28      1              188                      3
# 3   54      3              453                      3
# 4   40      1              775                      4
#
#    Departure/Arrival time convenient  Ease of Online booking  Gate location  \
# 0                                  3                       3              3
# 1                                  5                       5              5
# 2                                  5                       3              4
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food and drink  Online boarding  Seat comfort  ...  Baggage handling  \
# 0               2                2             2  ...                 3
# ...

# %% [markdown]
# #### **eda**

# %%
# Function to explore dataset
def explore_data(df):
    number_rows = df.shape[0]
    number_features = df.shape[1]
    data_types =df.dtypes

    print(f'Number of Rows{number_rows}')
    print(f'Number of  columns{number_features}')
    print(data_types)

explore_data(df)
# Out:
# Number of Rows20000
# Number of  columns23
# Age                                  int64
# Class                                int64
# Flight Distance                      int64
# Inflight wifi service                int64
# Departure/Arrival time convenient    int64
# Ease of Online booking               int64
# Gate location                        int64
# Food and drink                       int64
# Online boarding                      int64
# Seat comfort                         int64
# Inflight entertainment               int64
# On-board service                     int64
# Leg room service                     int64
# Baggage handling                     int64
# Checkin service                      int64
# Inflight service                     int64
# Cleanliness                          int64
# Departure Delay in Minutes           int64
# Arrival Delay in Minutes             int64
# Gender_Male                          int64
# Loyal Customer                       int64
# ...

# %%
# Function to perform EDA
def perform_eda(df):
    duplicates =df.duplicated().sum()
    missing_values = df.isna().sum()

    print(f'Number of duplicate rows: {duplicates}')
    print(f'\nNumber of missing values: {missing_values}')

perform_eda(df)
# Out:
# Number of duplicate rows: 0
#
# Number of missing values: Age                                  0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# Gender_Male                          0
# Loyal Customer                       0
# Business Travel                      0
# ...

# %%
# Summary statistics 
statistics = df.describe()
print(f'\nSummary Statistics')
statistics
# Out:
# Summary Statistics
#                 Age         Class  Flight Distance  Inflight wifi service  \
# count  20000.000000  20000.000000     20000.000000           20000.000000
# mean      39.477250      2.027800      1188.548000               2.727950
# std       15.108901      0.963054      1001.136957               1.326886
# min        7.000000      1.000000        31.000000               0.000000
# 25%       27.000000      1.000000       414.000000               2.000000
# 50%       40.000000      2.000000       842.000000               3.000000
# 75%       51.000000      3.000000      1733.000000               4.000000
# max       85.000000      3.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       20000.000000            20000.000000
# mean                            3.056100                2.751100
# std                             1.531134                1.396799
# ...

# %%
# Function to check all unique values and anomalies in the dataset
def check_column_values(df):
    print('Check all columns for anomalous values')

    #Loop through each column and return all unique values 
    for column_name in df.columns:
        print(f'Unique vlaues in: {column_name}')
        print(df[column_name].unique())
        print('\n')

check_column_values(df)
# Out:
# Check all columns for anomalous values
# Unique vlaues in: Age
# [26 52 28 54 40 79 41 24 49 59 21 57 25 22 29 48  9 30 42 17 32 44 27 43
#  46 37 53 23 12 33 10  7 15 65 20 34 31 39 56  8 60 36 69 58 62 51 47 16
#  63 38 72 70 64 18 71 35 45 68 55 11 67 14 19 50 66 61 13 77 80 85 73 75
#  74 78 76]
#
#
# Unique vlaues in: Class
# [3 1 2]
#
#
# Unique vlaues in: Flight Distance
# [2062  680  188 ... 3504 2875 1515]
#
#
# Unique vlaues in: Inflight wifi service
# [2 5 3 4 0 1]
#
#
# Unique vlaues in: Departure/Arrival time convenient
# [3 5 1 4 0 2]
#
#
# Unique vlaues in: Ease of Online booking
# [3 5 1 2 0 4]
#
#
# Unique vlaues in: Gate location
# [3 5 4 1 2 0]
#
#
# Unique vlaues in: Food and drink
# [2 3 4 5 1 0]
#
#
# Unique vlaues in: Online boarding
# [2 4 3 0 5 1]
#
#
# Unique vlaues in: Seat comfort
# [2 4 3 5 1]
#
#
# Unique vlaues in: Inflight entertainment
# [2 4 3 5 1 0]
#
#
# Unique vlaues in: On-board service
# [3 4 1 5 2 0]
#
#
# Unique vlaues in: Leg room service
# ...

# %% [markdown]
# ### **VISUALIZATION**

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# Format all figures in dark mode
plt.style.use('dark_background')

# Create correlation heatmap
def plot_correlation(df):
    fig, ax = plt.subplots(figsize=(10,6))

    # Define the mask for the upper triangle to avoid duplicates
    mask = np.triu(np.ones_like(df.corr(), dtype=bool))

    # plot heatmap 
    sns.heatmap(
        df.corr().round(2),
        ax=ax,
        mask=mask,
        vmin=-1,
        vmax=1,
        annot=True,
        cmap='BrBG'
    )

    ax.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18},pad=10)
    plt.show()

plot_correlation(df)

# %%
# Correlation heatmap as ranked
def ranked_correlation_heatmap(df, target_column):
    plt.figure(figsize=(4,8))
    heatmap= sns.heatmap(
        df.corr()[[target_column]].sort_values(by= target_column,ascending=False),
        vmin=-1,
        vmax=1,
        annot=True,
        cmap='BrBG'
    )

    heatmap.set_title('Features Correlating with Satisfied')
    plt.show()

ranked_correlation_heatmap(df, target_column='satisfied')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Create histogram and boxplot
def visualize_data(df,column_name):
    fig,axes=plt.subplots(
        figsize=(10,6),
        nrows=2,
        sharex=False
    )
    sns.set_style('dark')

    # Histogram
    sns.histplot(
        df[column_name],
        ax=axes[0],
        bins='auto',
        kde=True
    )
    axes[0].tick_params(axis='x', rotation=45)

    # Boxplot
    sns.boxplot(
        data=df,
        x=column_name,
        ax=axes[1]

    )
    plt.tight_layout()
    plt.show()

visualize_data(df, column_name='Inflight entertainment')

# %%
df.columns
# Out:
# Index(['Age', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'Gender_Male', 'Loyal Customer', 'Business Travel', 'satisfied'],
#       dtype='object')
